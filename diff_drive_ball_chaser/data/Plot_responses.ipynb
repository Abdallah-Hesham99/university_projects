# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fuzz = np.load('fuzzy_data.npy')

# %%
pid = np.load('pid_data.npy')

# %%
set1 = np.load('setpoint_data.npy')

# %%
set2 = np.load('setpoint2_data.npy')

# %%
plt.figure(figsize= (8,6))
plt.plot(fuzz)
plt.plot(pid)
plt.plot(set1)
plt.legend(['fuzzy_logic','PID','Setpoint'])
plt.title('responeses (setpoint = 3.14 rad) ')

plt.savefig('Combined_responses')
